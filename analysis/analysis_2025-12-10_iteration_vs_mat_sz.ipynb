# %%
import pandas as pd
from libs.parser import *

import matplotlib.pyplot as plt
from collections import defaultdict
from matplotlib.ticker import FuncFormatter

import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.colors import LogNorm

# %%
golf_ball_dir = "/u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/golf_ball"
old_dataset_dir = "/u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset"

# %%
data_all = []
for current_dir in [golf_ball_dir, old_dataset_dir]:
    for fname in os.listdir(current_dir):
        if "Pardiso" in fname:
            solver = "Eigen::PardisoLDLT"
        elif "AMGCL" in fname:
            solver = "AMGCL"
        elif "Hypre" in fname:
            solver = "Hypre"
        log_path = os.path.join(current_dir, fname)
        data = parse_log_file(log_path, solver)
        data_all.extend(data)
# Out:
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/golf_ball/Hypre_3D_golf_ball_189090_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/golf_ball/Hypre_3D_golf_ball_vanilla_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/golf_ball/Hypre_3D_golf_ball_113325_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/golf_ball/Hypre_3D_golf_ball_73852_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/golf_ball/Hypre_3D_golf_ball_39376_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/AMGCL_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_3D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-cliff-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_dolphin-funnel.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_spike-in-hole.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_ball-rollers.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_5-squares.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_friction-slope.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_edge-edge-parallel.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_wedge-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-spike-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-vertex-vertex.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_stretch-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-large-mass-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_disk-codim-points.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-large-stiffness-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_wedges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_walking-elephant.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_3D-arch.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_rod-twist.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_3D-cliff-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_golf-ball-doformable-wall.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_squeeze-out.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-arch.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-card-house.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_mat-twist.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_5-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_armadillo-roller.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_trash-compactor-shapes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_2D-edge-edge.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_circle-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_tet-corner.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_circle-rollers.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_3D-spike-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_3D-large-stiffness-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_mat-knives.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_3D-large-mass-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_3D-vertex-vertex.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_trash-compactor-octocat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_golf-ball-P2.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_screw.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2025-12-7/iteraion_mat_sz/old_dataset/Hypre_3D-card-house.log, some experiments are skipped.

# %%
print(data_all[0].keys())
# Out:
# dict_keys(['log_path', 'solver', 'bin_A', 'bin_b', 'mat_sz', 'nnz', 'density', 'sparsity', 'outer', 'inner', 'residual', 'clock_time', 'elapse_time', 'solver_tol', 'solver_maxiter', 'final_res_norm', 'num_iterations'])

# %%
grouped_data = []
for entry in data_all:
    solver = entry["solver"]
    mat_sz = entry["mat_sz"]
    elapse_time = entry["elapse_time"]
    if "num_iterations" in entry.keys():
        num_iterations = entry["num_iterations"]
    else:
        num_iterations = 0

    this_data = {
        "solver_name": solver,
        "mat_sz": mat_sz,
        "elapse_time": elapse_time,
        "num_iterations": num_iterations
    }
    grouped_data.append(this_data)

# %%
df = pd.DataFrame(grouped_data)
df["time_per_iter"] = df["elapse_time"] / df["num_iterations"]

# %%
# Filter num_thread = 1

solver_name = "Hypre"
df1 = df[df["mat_sz"]>=1e4]
df1 = df1[df1["solver_name"]==solver_name]
plt.figure(figsize=(8, 6))

# Scatter for each solver
sc = plt.scatter(
    df1["mat_sz"],
    df1["elapse_time"],
    c=df1["num_iterations"],
    cmap="plasma",
    norm=LogNorm()
)


plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"{solver_name}, elapse_time vs Matrix Size (num_thread = 1, log-log scatter)")
plt.colorbar(sc, label='Number of iterations')
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3781991/226675988.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Filter num_thread = 1

solver_name = "Hypre"
df1 = df[df["mat_sz"]>=1e4]
df1 = df1[df1["solver_name"]==solver_name]
plt.figure(figsize=(8, 6))

# Scatter for each solver
sc = plt.scatter(
    df1["mat_sz"],
    df1["time_per_iter"],
    c=df1["num_iterations"],
    cmap="plasma",
    norm=LogNorm()
)


plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("time_per_iter (s, log scale)")
plt.title(f"{solver_name}, elapse_time per iteration vs Matrix Size (num_thread = 1, log-log scatter)")
plt.colorbar(sc, label='Number of iterations')
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3781991/1956021915.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Filter num_thread = 1

solver_name = "AMGCL"
df1 = df[df["mat_sz"]>=1e4]
df1 = df1[df1["solver_name"]==solver_name]
plt.figure(figsize=(8, 6))

# Scatter for each solver
sc = plt.scatter(
    df1["mat_sz"],
    df1["elapse_time"],
    c=df1["num_iterations"],
    cmap="plasma",
    norm=LogNorm()
)


plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"{solver_name}, elapse_time vs Matrix Size (num_thread = 1, log-log scatter)")
plt.colorbar(sc, label='Number of iterations')
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3781991/3952011218.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Filter num_thread = 1

solver_name = "AMGCL"
df1 = df[df["mat_sz"]>=1e4]
df1 = df1[df1["solver_name"]==solver_name]
plt.figure(figsize=(8, 6))

# Scatter for each solver
sc = plt.scatter(
    df1["mat_sz"],
    df1["time_per_iter"],
    c=df1["num_iterations"],
    cmap="plasma",
    norm=LogNorm()
)


plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("time_per_iter (s, log scale)")
plt.title(f"{solver_name}, elapse_time per iteration vs Matrix Size (num_thread = 1, log-log scatter)")
plt.colorbar(sc, label='Number of iterations')
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3781991/1095402213.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df1 = df[df["mat_sz"]>=1e4]

plt.figure(figsize=(8, 6))

offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("solver_name"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["time_per_iter"],
        s=10,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset += .02

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("time_per_iter (s, log scale)")
plt.title("time_per_iter vs Matrix Size (num_thread = 1, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df1 = df[df["mat_sz"]>=1e4]

plt.figure(figsize=(8, 6))

offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("solver_name"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=5,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset += .02


plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title("elapse_time vs Matrix Size (num_thread = 1, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df1 = df[df["mat_sz"]>=1e4]

plt.figure(figsize=(8, 6))

offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("solver_name"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["num_iterations"],
        s=5,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset += .02

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("num_iterations ( log scale)")
plt.title("num_iterations vs Matrix Size (num_thread = 1, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
