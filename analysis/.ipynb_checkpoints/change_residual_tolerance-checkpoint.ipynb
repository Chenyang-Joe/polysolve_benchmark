# %%
# %matplotlib inline
import json
import collections
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from statsmodels.nonparametric.kernel_regression import KernelReg

import seaborn as sns
import matplotlib.patches as mpatches
from matplotlib.ticker import FuncFormatter
from matplotlib import font_manager

from scipy.stats import gaussian_kde
import re

# %%
def get_mat_sz(fp):
    try:
        # the first 8 values are: dim, is_spd, is_sequence, nrow, ncol, nnz, outer_sz, inner_sz
        # nnz, number of non-zero element
        meta = np.fromfile(fp, dtype=np.int32, count=8, offset=0)
        n_rows = meta[3]
        return n_rows
    except:
        print("mat size exception")
        return None

def get_nnz(fp):
    try:
        meta = np.fromfile(fp, dtype=np.int32, count=8, offset=0)
        nnz = meta[5]
        return nnz
    except:
        print("nnz exception")
        return None

def get_density(nnz, mat_sz):
    if nnz is None or mat_sz is None:
        return None
    else:
        nnz =  np.float128(nnz)
        mat_sz =  np.float128(mat_sz)
        return (nnz + 1e-10) / (mat_sz * mat_sz + 1e-10)

def get_sparsity(nnz, mat_sz):
    if nnz is None or mat_sz is None:
        return None
    else:
        nnz =  np.float128(nnz)
        mat_sz =  np.float128(mat_sz)
        return (mat_sz * mat_sz - nnz) / (mat_sz * mat_sz)

# %%
def sequence_data(fname):
    if not os.path.exists(fname):
        print(fname)
        return None    
    seq = []
    with open(fname, 'r') as f:
        for line in f.readlines():
            try:
                time = float(line.split(" ")[4])
                mem = float(line.split(" ")[5])
                seq.append([time, mem])
            except:
                seq.append([-1, -1])
                continue
    if len(seq) == 0:
        return None
    return seq

def sequence_data_trillinos(fname):
    if not os.path.exists(fname):
        return None    
    seq = []
    with open(fname, 'r') as f:
        for line in f.readlines():
            if "[BOS]" in line:
                time = float(line.split(" ")[0].strip("[BOS]").strip("[EOS]"))
                mem = float(line.split(" ")[1])
                seq.append([time, mem])
            elif "Aborted (core dumped)" in line:
                seq.append([-1, -1])

    if len(seq) == 0:
        return None
    return seq

def sequence_data_hypre(fname):
    if not os.path.exists(fname):
        return None    
    seq = []
    with open(fname, 'r') as f:
        for line in f.readlines():
            if "hypre error" in line:
                seq.append([-1, -1])
                continue
            if "hypre" not in line:
                try:
                    time = float(line.split(" ")[4])
                    mem = float(line.split(" ")[5])
                    seq.append([time, mem])
                except:
                    continue

    if len(seq) == 0:
        return None
    return seq

def check_bin_log(bin_path, log_file):
    start_i = 0
    start_j = 1
    end_i = 1000
    end_j = 1000

    
#     if os.path.exists(log_file):
#         with open(log_file,"r")as f:
#             last_line=f.readlines()[-1]
#             last_i=int(last_line.split(" ")[1])
#             last_j=int(last_line.split(" ")[2])
#         start_i=last_i+1
#         start_j=last_j+1
    
#     search_i = 1
#     while(search_i < 10000):
#         if os.path.exists(os.path.join(bin_path,"%d_%d_A.bin"%(search_i,1))):
#             break
#         search_i += 1

#     start_i = search_i

#     seq = []    
#     i = start_i
#     j = start_j
#     fp_a=os.path.join(bin_path,"%d_%d_A.bin"%(i,j))
#     fp_b=os.path.join(bin_path,"%d_%d_b.bin"%(i,j))
    i = start_i
    j = start_j
    search_first_file = False
    for out_i in range(start_i,end_i):
        for in_j in range(start_j,end_j):
            fp_a=os.path.join(bin_path,"%d_%d_A.bin"%(out_i,in_j))
            if os.path.exists(fp_a):
                i = out_i
                j = in_j
                search_first_file = True
                fp_b=os.path.join(bin_path,"%d_%d_b.bin"%(out_i,in_j))
                break
        if search_first_file:
#             print("found")
            break
    seq = []    
    
    while(os.path.exists(fp_a) and i < end_i):
        while(os.path.exists(fp_a) and j < end_j):
#     while(i < end_i):
#         while(j < end_j):
            if (os.path.exists(fp_a)):
                seq.append([i,j,fp_a, fp_b])
            j += 1
            fp_a=os.path.join(bin_path,"%d_%d_A.bin"%(i,j))
            fp_b=os.path.join(bin_path,"%d_%d_b.bin"%(i,j))
        j = 1
        i += 1
        fp_a=os.path.join(bin_path,"%d_%d_A.bin"%(i,j))
        fp_b=os.path.join(bin_path,"%d_%d_b.bin"%(i,j))
        
        
    return seq

# %%
def sequence_data_new(fname, solver):
    begin_line = []
    end_line = []
    with open(fname, 'r') as f:
        lines = f.readlines()  # read all lines into a list

    for i, line in enumerate(lines):
        if "[EXPBEGIN]" in line:
            begin_line.append(i)
        if "[EXPEND]" in line:
            end_line.append(i)

    len_begin = len(begin_line)
    len_end = len(end_line)
    if len_begin != len_end:
        print("#[EXPBEGIN] #[EXPEND] mismatches, unknown error formats.")

    begin_correct = []
    end_correct = []

    for begin_i, end_i in zip(begin_line, end_line):
        error_detected = False
        for j in range(begin_i, end_i):
            if "ERROR" in lines[j] or "error" in lines[j]:
#                 print(f"errors between {begin_i+1} line and {end_i+1} line")
                error_detected = True
                break
        if error_detected:
            continue 
        begin_correct.append(begin_i)
        end_correct.append(end_i)
    if error_detected:
        print("error in current exp: ", fname)


    seq = []
    for begin_i, end_i in zip(begin_correct, end_correct):
        element = {}
        element["solver_tol"] = float(lines[end_i-7].split(" ")[-1].strip())
        element["solver_maxiter"] = float(lines[end_i-6].split(" ")[-1].strip())
        element["final_res_norm"] = float(lines[end_i-5].split(" ")[-1].strip())
        element["num_iterations"] = float(lines[end_i-4].split(" ")[-1].strip())
        element["norm_b"] = float(lines[end_i-3].split(" ")[-1].strip())
        element["clock_time"] = float(lines[end_i-2].split(" ")[-1].strip().rstrip("s"))
        element["elapse_time"] = float(lines[end_i-1].split(" ")[-1].strip().rstrip("s"))
        
        if solver == "AMGCL":
            element["factorize"] = float(lines[end_i-11].split(" ")[-1].strip().rstrip("s"))
            element["solve"] = float(lines[end_i-10].split(" ")[-1].strip().rstrip("s"))
        seq.append(element)
    return seq

# %% [markdown]
# # Read data

# %%
df_all = pd.DataFrame()

# %% [markdown]
# # read data 1

# %%
# Set your directories accordingly
# Please adjust the following paths as needed
data_dir = "/u/1/chenyang/benchmark_data/matrix_resource/data-all" 
mat_dir = "/u/1/chenyang/benchmark_data/matrix_resource/solver-mat-0906"
result_dir = "/u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand"  # experiment metrics apart from mat
save_dir = "/u/1/chenyang/benchmark/analysis/output_test"
# solver_list = ["Pardiso", "Trilinos", "Trilinos-nullspace", "AMGCL", "Hypre"]
# solver_list = ["Pardiso", "AMGCL", "Hypre"]
solver_list = ["AMGCL", "Hypre"]

if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
# solver_list = [solver_list[2]]
# print(solver_list)

with open(os.path.join(data_dir, "filenames.json"), "r") as f:
    filenames = json.load(f)
    prenames = filenames["prenames"] # experiment name
    fpaths = filenames["fpaths"] # corresponding json file

    data_load = []
#     for solver in solver_list:
#         data_load[solver] = []

    for solver in solver_list:           
        for fpath, prename in zip(fpaths, prenames):
        
            fp = "%s/%s/%s.log" % (result_dir, solver, prename) #fp is final concat file path
            if not os.path.exists(fp):
                print(fp, "does not exist")
                continue
            seq_data = sequence_data_new(fp, solver)
            
            
#             if solver == "Trilinos" or solver == "Trilinos-nullspace":
#                 seq_data = sequence_data_trillinos(fp)
#             elif solver == "Hypre":
#                 seq_data = sequence_data_hypre(fp)
#             else:
#                 seq_data = sequence_data(fp)



            if len(seq_data) == 0:
                print("no log for this prename: ", prename, solver)
                break
#             print("seq_data lens: ", len(seq_data), "prename: ",prename )
     
    
            # evaluate whether #result = #bin, so the exps are correctly done
            bin_path = os.path.join(mat_dir, prename)
            bin_logged = check_bin_log(bin_path, fp)
#             print("bin_logged lens: ", len(bin_logged), "prename: ",prename )

            if len(seq_data) != len(bin_logged):
                print(solver, prename, "lens mismatching", "seq_data: ", len(seq_data), " bin_logged: ", len(bin_logged))
#             else:
#                 print(solver, prename, "lens matching", "seq_data: ", len(seq_data), " bin_logged: ", len(bin_logged))
                
            for element, bin_file in zip(seq_data , bin_logged):
                single_trial = {}
                single_trial["fpath"] = fpath
                single_trial["prename"] = prename
                single_trial["outer_i"] = bin_file[0]
                single_trial["inner_j"] = bin_file[1]
                single_trial["solver"] = solver
                single_trial["mat_sz"] = get_mat_sz(bin_file[2])
                single_trial["nnz"] = get_nnz(bin_file[2])
                single_trial["density"] = get_density(single_trial["nnz"], single_trial["mat_sz"])
                single_trial["sparsity"] = get_sparsity(single_trial["nnz"], single_trial["mat_sz"])

                single_trial["solver_tol"] = element["solver_tol"]
                single_trial["solver_maxiter"] = element["solver_maxiter"] 
                single_trial["final_res_norm"] = element["final_res_norm"] 
                single_trial["num_iterations"] = element["num_iterations"] 
                single_trial["norm_b"] = element["norm_b"]
                single_trial["clock_time"] = element["clock_time"]
                single_trial["elapse_time"] = element["elapse_time"]

                if solver == "AMGCL":
                    single_trial["factorize"] = element["factorize"]
                    single_trial["solve"] = element["solve"]
                    
                    
                data_load.append(single_trial)



    columns = ["fpath",     
               "prename", 
               "outer_i",
               "inner_j",
               "solver",
               "mat_sz",
               "nnz",
               "density",
               "sparsity",
               "solver_tol",
               "solver_maxiter",
               "final_res_norm",
               "num_iterations",
               "norm_b",
               "clock_time",
               "elapse_time"
              ]
    
    

    columns_more = ["factorize", "solve"]
    columns = columns + columns_more


    writer = pd.ExcelWriter(os.path.join(save_dir, 'profiling.xlsx'))
    df_load = pd.DataFrame(data_load, columns=columns)
    
#     #******log******
    
#     columns_log = [
#        "mat_sz",
#        "nnz",
#        "density",
#        "sparsity"]

#     mask = (df_load[columns_log] > 0).all(axis=1)
#     df_load_clean = df_load[mask].copy()
    
#     for col in columns_log:
#         df_load[col + "_log"] = np.log10(df_load_clean[col] + 1e-10)  # 防止 log(0)
        
#     print(df_load[[col + "_log" for col in columns_log]].head())    
#     #******log******

    print(df_load[[col for col in columns]].head())    
    df_load.to_excel(writer)
    writer.close()

df_all = pd.concat([df_all, df_load], axis=0, ignore_index=True)
print(f"There are {len(df_all)} elements in df_all")
print(df_all.iloc[-1]["solver_tol"])
print(df_all["solver_tol"].unique())
# Out:
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/kick.log does not exist
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/5-cubes-hex-fast.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/5-cubes-hex.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/two-cubes.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/union.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/helmholtz.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/stokes_static.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/plate_hole.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/hooke.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/laplace_ws.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/point_selection.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/laplace_mv.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/navier_stokes_static.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/laplace.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/unconstrained_ogden.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/incompressible_ogden.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/navier_stokes_transient.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/laplace_quad.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/AMGCL/neohookean.log does not exist
# Hypre golf-ball-doformable-wall lens mismatching seq_data:  183  bin_logged:  326
# Hypre circle-rollers lens mismatching seq_data:  2754  bin_logged:  5279
# error in current exp:  /u/1/chenyang/benchmark_data/exp-result/20250628_logging_expand/Hypre/2D-arch.log
# no log for this prename:  2D-arch Hypre
#                                                fpath  \
# 0  /home/yibo/myrepo/polyfem/data/contact/example...
# 1  /home/yibo/myrepo/polyfem/data/contact/example...
# 2  /home/yibo/myrepo/polyfem/data/contact/example...
# 3  /home/yibo/myrepo/polyfem/data/contact/example...
# 4  /home/yibo/myrepo/polyfem/data/contact/example...
#
#                     prename  outer_i  inner_j solver  mat_sz   nnz  density  \
# 0  initial_angular_velocity        1        1  AMGCL     8.0  56.0    0.875
# 1  initial_angular_velocity        1        2  AMGCL     8.0  56.0    0.875
# 2  initial_angular_velocity        1        3  AMGCL     8.0  56.0    0.875
# 3  initial_angular_velocity        1        4  AMGCL     8.0  56.0    0.875
# 4  initial_angular_velocity        2        1  AMGCL     8.0  56.0    0.875
#
#    sparsity    solver_tol  solver_maxiter  final_res_norm  num_iterations  \
# 0     0.125  1.000000e-10          1000.0    1.437600e-15             2.0
# 1     0.125  1.000000e-10          1000.0    2.661600e-18             4.0
# 2     0.125  1.000000e-10          1000.0    9.300300e-18             4.0
# 3     0.125  1.000000e-10          1000.0    2.768000e-15             4.0
# 4     0.125  1.000000e-10          1000.0    2.529700e-17             4.0
#
#        norm_b  clock_time  elapse_time  factorize     solve
# 0   79.615000    0.000935     0.000935   0.000568  0.000345
# 1  864.870000    0.000789     0.000789   0.000357  0.000414
# 2    7.793000    0.000802     0.000802   0.000363  0.000417
# 3    0.000622    0.001038     0.001037   0.000583  0.000425
# 4   78.993000    0.001100     0.001099   0.000557  0.000511
# There are 55835 elements in df_all
# 1e-10
# [1.e-10]

# %% [markdown]
# # read data 2

# %%
# Set your directories accordingly
# Please adjust the following paths as needed
data_dir = "/u/1/chenyang/benchmark_data/matrix_resource/data-all" 
mat_dir = "/u/1/chenyang/benchmark_data/matrix_resource/solver-mat-0906"
result_dir = "/u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance"  # experiment metrics apart from mat
save_dir = "/u/1/chenyang/benchmark/analysis/output_test"
# solver_list = ["Pardiso", "Trilinos", "Trilinos-nullspace", "AMGCL", "Hypre"]
# solver_list = ["Pardiso", "AMGCL", "Hypre"]
solver_list = ["AMGCL", "Hypre"]

if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
# solver_list = [solver_list[2]]
# print(solver_list)

with open(os.path.join(data_dir, "filenames.json"), "r") as f:
    filenames = json.load(f)
    prenames = filenames["prenames"] # experiment name
    fpaths = filenames["fpaths"] # corresponding json file

    data_load = []
#     for solver in solver_list:
#         data_load[solver] = []

    for solver in solver_list:           
        for fpath, prename in zip(fpaths, prenames):
        
            fp = "%s/%s/%s.log" % (result_dir, solver, prename) #fp is final concat file path
            if not os.path.exists(fp):
                print(fp, "does not exist")
                continue
            seq_data = sequence_data_new(fp, solver)
            
            
#             if solver == "Trilinos" or solver == "Trilinos-nullspace":
#                 seq_data = sequence_data_trillinos(fp)
#             elif solver == "Hypre":
#                 seq_data = sequence_data_hypre(fp)
#             else:
#                 seq_data = sequence_data(fp)



            if len(seq_data) == 0:
                print("no log for this prename: ", prename, solver)
                break
#             print("seq_data lens: ", len(seq_data), "prename: ",prename )
     
    
            # evaluate whether #result = #bin, so the exps are correctly done
            bin_path = os.path.join(mat_dir, prename)
            bin_logged = check_bin_log(bin_path, fp)
#             print("bin_logged lens: ", len(bin_logged), "prename: ",prename )

            if len(seq_data) != len(bin_logged):
                print(solver, prename, "lens mismatching", "seq_data: ", len(seq_data), " bin_logged: ", len(bin_logged))
#             else:
#                 print(solver, prename, "lens matching", "seq_data: ", len(seq_data), " bin_logged: ", len(bin_logged))
                
            for element, bin_file in zip(seq_data , bin_logged):
                single_trial = {}
                single_trial["fpath"] = fpath
                single_trial["prename"] = prename
                single_trial["outer_i"] = bin_file[0]
                single_trial["inner_j"] = bin_file[1]
                single_trial["solver"] = solver
                single_trial["mat_sz"] = get_mat_sz(bin_file[2])
                single_trial["nnz"] = get_nnz(bin_file[2])
                single_trial["density"] = get_density(single_trial["nnz"], single_trial["mat_sz"])
                single_trial["sparsity"] = get_sparsity(single_trial["nnz"], single_trial["mat_sz"])

                single_trial["solver_tol"] = element["solver_tol"]
                single_trial["solver_maxiter"] = element["solver_maxiter"] 
                single_trial["final_res_norm"] = element["final_res_norm"] 
                single_trial["num_iterations"] = element["num_iterations"] 
                single_trial["norm_b"] = element["norm_b"]
                single_trial["clock_time"] = element["clock_time"]
                single_trial["elapse_time"] = element["elapse_time"]

                if solver == "AMGCL":
                    single_trial["factorize"] = element["factorize"]
                    single_trial["solve"] = element["solve"]
                    
                    
                data_load.append(single_trial)



    columns = ["fpath",     
               "prename", 
               "outer_i",
               "inner_j",
               "solver",
               "mat_sz",
               "nnz",
               "density",
               "sparsity",
               "solver_tol",
               "solver_maxiter",
               "final_res_norm",
               "num_iterations",
               "norm_b",
               "clock_time",
               "elapse_time"
              ]
    
    

    columns_more = ["factorize", "solve"]
    columns = columns + columns_more


    writer = pd.ExcelWriter(os.path.join(save_dir, 'profiling.xlsx'))
    df_load = pd.DataFrame(data_load, columns=columns)
    
#     #******log******
    
#     columns_log = [
#        "mat_sz",
#        "nnz",
#        "density",
#        "sparsity"]

#     mask = (df_load[columns_log] > 0).all(axis=1)
#     df_load_clean = df_load[mask].copy()
    
#     for col in columns_log:
#         df_load[col + "_log"] = np.log10(df_load_clean[col] + 1e-10)  # 防止 log(0)
        
#     print(df_load[[col + "_log" for col in columns_log]].head())    
#     #******log******

    print(df_load[[col for col in columns]].head())    
    df_load.to_excel(writer)
    writer.close()

df_all = pd.concat([df_all, df_load], axis=0, ignore_index=True)
print(f"There are {len(df_all)} elements in df_all")
print(df_all.iloc[-1]["solver_tol"])
print(df_all["solver_tol"].unique())
# Out:
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/kick.log does not exist
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/5-cubes-hex-fast.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/5-cubes-hex.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/two-cubes.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/union.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/helmholtz.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/stokes_static.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/plate_hole.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/hooke.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/laplace_ws.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/point_selection.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/laplace_mv.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/navier_stokes_static.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/laplace.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/unconstrained_ogden.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/incompressible_ogden.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/navier_stokes_transient.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/laplace_quad.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/AMGCL/neohookean.log does not exist
# Hypre golf-ball-doformable-wall lens mismatching seq_data:  184  bin_logged:  326
# Hypre circle-rollers lens mismatching seq_data:  2754  bin_logged:  5279
# error in current exp:  /u/1/chenyang/benchmark_data/exp-result/20250702_change_tolerance/Hypre/2D-arch.log
# no log for this prename:  2D-arch Hypre
#                                                fpath  \
# 0  /home/yibo/myrepo/polyfem/data/contact/example...
# 1  /home/yibo/myrepo/polyfem/data/contact/example...
# 2  /home/yibo/myrepo/polyfem/data/contact/example...
# 3  /home/yibo/myrepo/polyfem/data/contact/example...
# 4  /home/yibo/myrepo/polyfem/data/contact/example...
#
#                     prename  outer_i  inner_j solver  mat_sz   nnz  density  \
# 0  initial_angular_velocity        1        1  AMGCL     8.0  56.0    0.875
# 1  initial_angular_velocity        1        2  AMGCL     8.0  56.0    0.875
# 2  initial_angular_velocity        1        3  AMGCL     8.0  56.0    0.875
# 3  initial_angular_velocity        1        4  AMGCL     8.0  56.0    0.875
# 4  initial_angular_velocity        2        1  AMGCL     8.0  56.0    0.875
#
#    sparsity    solver_tol  solver_maxiter  final_res_norm  num_iterations  \
# 0     0.125  1.000000e-08          1000.0    1.437600e-15             2.0
# 1     0.125  1.000000e-08          1000.0    5.692600e-09             3.0
# 2     0.125  1.000000e-08          1000.0    9.300300e-18             4.0
# 3     0.125  1.000000e-08          1000.0    2.768000e-15             4.0
# 4     0.125  1.000000e-08          1000.0    2.529700e-17             4.0
#
#        norm_b  clock_time  elapse_time  factorize     solve
# 0   79.615000    0.001081     0.001080   0.000620  0.000421
# 1  864.870000    0.001214     0.001214   0.000592  0.000580
# 2    7.793000    0.001318     0.001317   0.000583  0.000707
# 3    0.000622    0.001185     0.001184   0.000609  0.000544
# 4   78.993000    0.000811     0.000811   0.000385  0.000404
# There are 111671 elements in df_all
# 1e-08
# [1.e-10 1.e-08]

# %% [markdown]
# # Read data 3

# %%
# Set your directories accordingly
# Please adjust the following paths as needed
data_dir = "/u/1/chenyang/benchmark_data/matrix_resource/data-all" 
mat_dir = "/u/1/chenyang/benchmark_data/matrix_resource/solver-mat-0906"
result_dir = "/u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance"  # experiment metrics apart from mat
save_dir = "/u/1/chenyang/benchmark/analysis/output_test"
# solver_list = ["Pardiso", "Trilinos", "Trilinos-nullspace", "AMGCL", "Hypre"]
# solver_list = ["Pardiso", "AMGCL", "Hypre"]
solver_list = ["AMGCL", "Hypre"]

if not os.path.exists(save_dir):
    os.makedirs(save_dir)
    
# solver_list = [solver_list[2]]
# print(solver_list)

with open(os.path.join(data_dir, "filenames.json"), "r") as f:
    filenames = json.load(f)
    prenames = filenames["prenames"] # experiment name
    fpaths = filenames["fpaths"] # corresponding json file

    data_load = []
#     for solver in solver_list:
#         data_load[solver] = []

    for solver in solver_list:           
        for fpath, prename in zip(fpaths, prenames):
        
            fp = "%s/%s/%s.log" % (result_dir, solver, prename) #fp is final concat file path
            if not os.path.exists(fp):
                print(fp, "does not exist")
                continue
            seq_data = sequence_data_new(fp, solver)
            
            
#             if solver == "Trilinos" or solver == "Trilinos-nullspace":
#                 seq_data = sequence_data_trillinos(fp)
#             elif solver == "Hypre":
#                 seq_data = sequence_data_hypre(fp)
#             else:
#                 seq_data = sequence_data(fp)



            if len(seq_data) == 0:
                print("no log for this prename: ", prename, solver)
                break
#             print("seq_data lens: ", len(seq_data), "prename: ",prename )
     
    
            # evaluate whether #result = #bin, so the exps are correctly done
            bin_path = os.path.join(mat_dir, prename)
            bin_logged = check_bin_log(bin_path, fp)
#             print("bin_logged lens: ", len(bin_logged), "prename: ",prename )

            if len(seq_data) != len(bin_logged):
                print(solver, prename, "lens mismatching", "seq_data: ", len(seq_data), " bin_logged: ", len(bin_logged))
#             else:
#                 print(solver, prename, "lens matching", "seq_data: ", len(seq_data), " bin_logged: ", len(bin_logged))
                
            for element, bin_file in zip(seq_data , bin_logged):
                single_trial = {}
                single_trial["fpath"] = fpath
                single_trial["prename"] = prename
                single_trial["outer_i"] = bin_file[0]
                single_trial["inner_j"] = bin_file[1]
                single_trial["solver"] = solver
                single_trial["mat_sz"] = get_mat_sz(bin_file[2])
                single_trial["nnz"] = get_nnz(bin_file[2])
                single_trial["density"] = get_density(single_trial["nnz"], single_trial["mat_sz"])
                single_trial["sparsity"] = get_sparsity(single_trial["nnz"], single_trial["mat_sz"])

                single_trial["solver_tol"] = element["solver_tol"]
                single_trial["solver_maxiter"] = element["solver_maxiter"] 
                single_trial["final_res_norm"] = element["final_res_norm"] 
                single_trial["num_iterations"] = element["num_iterations"] 
                single_trial["norm_b"] = element["norm_b"]
                single_trial["clock_time"] = element["clock_time"]
                single_trial["elapse_time"] = element["elapse_time"]

                if solver == "AMGCL":
                    single_trial["factorize"] = element["factorize"]
                    single_trial["solve"] = element["solve"]
                    
                    
                data_load.append(single_trial)



    columns = ["fpath",     
               "prename", 
               "outer_i",
               "inner_j",
               "solver",
               "mat_sz",
               "nnz",
               "density",
               "sparsity",
               "solver_tol",
               "solver_maxiter",
               "final_res_norm",
               "num_iterations",
               "norm_b",
               "clock_time",
               "elapse_time"
              ]
    
    

    columns_more = ["factorize", "solve"]
    columns = columns + columns_more


    writer = pd.ExcelWriter(os.path.join(save_dir, 'profiling.xlsx'))
    df_load = pd.DataFrame(data_load, columns=columns)
    
#     #******log******
    
#     columns_log = [
#        "mat_sz",
#        "nnz",
#        "density",
#        "sparsity"]

#     mask = (df_load[columns_log] > 0).all(axis=1)
#     df_load_clean = df_load[mask].copy()
    
#     for col in columns_log:
#         df_load[col + "_log"] = np.log10(df_load_clean[col] + 1e-10)  # 防止 log(0)
        
#     print(df_load[[col + "_log" for col in columns_log]].head())    
#     #******log******

    print(df_load[[col for col in columns]].head())    
    df_load.to_excel(writer)
    writer.close()

df_all = pd.concat([df_all, df_load], axis=0, ignore_index=True)
print(f"There are {len(df_all)} elements in df_all")
print(df_all.iloc[-1]["solver_tol"])
print(df_all["solver_tol"].unique())
# Out:
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/kick.log does not exist
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# mat size exception
# nnz exception
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/5-cubes-hex-fast.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/5-cubes-hex.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/two-cubes.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/union.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/helmholtz.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/stokes_static.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/plate_hole.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/hooke.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/laplace_ws.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/point_selection.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/laplace_mv.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/navier_stokes_static.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/laplace.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/unconstrained_ogden.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/incompressible_ogden.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/navier_stokes_transient.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/laplace_quad.log does not exist
# /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/AMGCL/neohookean.log does not exist
# Hypre golf-ball-doformable-wall lens mismatching seq_data:  183  bin_logged:  326
# Hypre circle-rollers lens mismatching seq_data:  2754  bin_logged:  5279
# error in current exp:  /u/1/chenyang/benchmark_data/exp-result/20250704_change_tolerance/Hypre/2D-arch.log
# no log for this prename:  2D-arch Hypre
#                                                fpath  \
# 0  /home/yibo/myrepo/polyfem/data/contact/example...
# 1  /home/yibo/myrepo/polyfem/data/contact/example...
# 2  /home/yibo/myrepo/polyfem/data/contact/example...
# 3  /home/yibo/myrepo/polyfem/data/contact/example...
# 4  /home/yibo/myrepo/polyfem/data/contact/example...
#
#                     prename  outer_i  inner_j solver  mat_sz   nnz  density  \
# 0  initial_angular_velocity        1        1  AMGCL     8.0  56.0    0.875
# 1  initial_angular_velocity        1        2  AMGCL     8.0  56.0    0.875
# 2  initial_angular_velocity        1        3  AMGCL     8.0  56.0    0.875
# 3  initial_angular_velocity        1        4  AMGCL     8.0  56.0    0.875
# 4  initial_angular_velocity        2        1  AMGCL     8.0  56.0    0.875
#
#    sparsity    solver_tol  solver_maxiter  final_res_norm  num_iterations  \
# 0     0.125  1.000000e-09          1000.0    1.437600e-15             2.0
# 1     0.125  1.000000e-09          1000.0    2.661600e-18             4.0
# 2     0.125  1.000000e-09          1000.0    9.300300e-18             4.0
# 3     0.125  1.000000e-09          1000.0    2.768000e-15             4.0
# 4     0.125  1.000000e-09          1000.0    2.529700e-17             4.0
#
#        norm_b  clock_time  elapse_time  factorize     solve
# 0   79.615000    0.000587     0.000586   0.000355  0.000210
# 1  864.870000    0.001257     0.001257   0.000559  0.000676
# 2    7.793000    0.001308     0.001308   0.000592  0.000683
# 3    0.000622    0.001293     0.001293   0.000575  0.000687
# 4   78.993000    0.001322     0.001321   0.000592  0.000691
# There are 167506 elements in df_all
# 1e-09
# [1.e-10 1.e-08 1.e-09]

# %% [markdown]
# # Overall plot

# %%
# df_now = df_all[df_all["solver"] == "Trilinos"]
df_now = df_all[df_all["solver"] == "AMGCL"]


tol_values = np.sort(df_all["solver_tol"].unique())

n = len(tol_values)

fig, axes = plt.subplots(n, 1, figsize=(5, 4*n), sharex=True, sharey=True)

for ax, tol in zip(axes, tol_values):
    df_tol = df_all[
        (df_all["solver"] == "AMGCL") &
        (df_all["solver_tol"] == tol)
    ]
    ax.scatter(
        np.log(df_tol["mat_sz"]),
        np.log(df_tol["elapse_time"]),
        alpha=0.7,
        s=10,
    )
    ax.set_title(f"tol = {tol:.0e}")
    ax.set_xlabel("log(mat_sz)")
    ax.set_ylabel("log(elapse_time)")

plt.suptitle("AMGCL: elapse_time vs mat_sz by solver_tol", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scattering plot

# %%
df_now = df_all[
    (df_all["prename"] == "golf-ball-doformable-wall")
]

tol_values = np.sort(df_all["solver_tol"].unique())

n = len(tol_values)

fig, axes = plt.subplots(n, 1, figsize=(5, 4*n), sharex=True, sharey=True)

for ax, tol in zip(axes, tol_values):
    df_tol = df_now[
        (df_now["solver"] == "AMGCL") &
        (df_now["solver_tol"] == tol)
    ]
    ax.scatter(df_tol["elapse_time"], df_tol["num_iterations"], alpha=0.7, s=10)

    ax.set_title(f"tol = {tol:.0e}")
    ax.set_xlabel("Elapse Time (s)")
    ax.set_ylabel("Number of Iterations")

plt.suptitle("AMGCL: elapse_time vs num_iterations\nfor golf-ball-doformable-wall", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scattering plot

# %%
df_now = df_all[
    (df_all["prename"] == "golf-ball-doformable-wall") &
        (df_all["final_res_norm"] < 100)
]

tol_values = np.sort(df_all["solver_tol"].unique())

n = len(tol_values)

fig, axes = plt.subplots(n, 1, figsize=(5, 4*n), sharex=True, sharey=True)

for ax, tol in zip(axes, tol_values):
    df_tol = df_now[
        (df_now["solver"] == "AMGCL") &
        (df_now["solver_tol"] == tol)
    ]
    ax.scatter(df_tol["num_iterations"], df_tol["final_res_norm"], alpha=0.7, s=10)

    ax.set_title(f"tol = {tol:.0e}")
    ax.set_xlabel("num_iterations")
    ax.set_ylabel("final_res_norm")

plt.suptitle("AMGCL: elapse_time vs final_res_norm\nfor golf-ball-doformable-wall", y=1.02)
plt.tight_layout()
plt.show()

# %%
tol = np.sort(df_all["solver_tol"].unique())[0]
cut = tol

df_now = df_all[
    (df_all["solver"] == "AMGCL") &
    (df_all["prename"] == "golf-ball-doformable-wall") &
    (df_all["solver_tol"] == tol)&
    (df_all["final_res_norm"] < cut)
    
]

print(np.sort(df_now["solver_tol"].unique()))

plt.figure(figsize=(8, 6))
plt.scatter(df_now["num_iterations"], df_now["final_res_norm"], alpha=0.7, s=10)

plt.xlabel("num_iterations")
plt.ylabel("final_res_norm")
plt.title(f"AMGCL: elapse_time vs final_res_norm\nfor golf-ball-doformable-wall, tol = {tol}, cut = {cut}")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [1.e-10]

# %%
tol = np.sort(df_all["solver_tol"].unique())[1]
cut = tol

df_now = df_all[
    (df_all["solver"] == "AMGCL") &
    (df_all["prename"] == "golf-ball-doformable-wall") &
    (df_all["solver_tol"] == tol)&
    (df_all["final_res_norm"] < cut)
    
]

print(np.sort(df_now["solver_tol"].unique()))

plt.figure(figsize=(8, 6))
plt.scatter(df_now["num_iterations"], df_now["final_res_norm"], alpha=0.7, s=10)

plt.xlabel("num_iterations")
plt.ylabel("final_res_norm")
plt.title(f"AMGCL: elapse_time vs final_res_norm\nfor golf-ball-doformable-wall, tol = {tol}, cut = {cut}")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [1.e-09]

# %%
tol = np.sort(df_all["solver_tol"].unique())[2]
cut = tol

df_now = df_all[
    (df_all["solver"] == "AMGCL") &
    (df_all["prename"] == "golf-ball-doformable-wall") &
    (df_all["solver_tol"] == tol)&
    (df_all["final_res_norm"] < cut)
    
]

print(np.sort(df_now["solver_tol"].unique()))

plt.figure(figsize=(8, 6))
plt.scatter(df_now["num_iterations"], df_now["final_res_norm"], alpha=0.7, s=10)

plt.xlabel("num_iterations")
plt.ylabel("final_res_norm")
plt.title(f"AMGCL: elapse_time vs final_res_norm\nfor golf-ball-doformable-wall, tol = {tol}, cut = {cut}")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [1.e-08]

# %% [markdown]
# # Distribution

# %%
tol = np.sort(df_all["solver_tol"].unique())[0]
cut = 1e-10

df_now = df_all[
    (df_all["solver"] == "AMGCL") &
    (df_all["prename"] == "golf-ball-doformable-wall") &
    (df_all["solver_tol"] == tol)&
    (df_all["final_res_norm"] < cut)
    
]

data = df_now["num_iterations"].values
density = gaussian_kde(data)
xs = np.linspace(data.min(), data.max(), 200)

plt.figure(figsize=(8, 4))
plt.plot(xs, density(xs))
plt.fill_between(xs, density(xs), alpha=0.3)
plt.xlabel("num_iterations")
plt.ylabel("Density")
plt.title(f"KDE of num_iterations, res_tol = {tol}, cut = {cut}")
plt.tight_layout()
plt.show()

# %%
tol = np.sort(df_all["solver_tol"].unique())[0]
cut = 1e-10

df_now = df_all[
    (df_all["solver"] == "AMGCL") &
    (df_all["prename"] == "golf-ball-doformable-wall") &
    (df_all["solver_tol"] == tol)&
    (df_all["final_res_norm"] < cut)
    
]

data = df_now["num_iterations"].values
density = gaussian_kde(data)
xs = np.linspace(data.min(), data.max(), 200)

plt.figure(figsize=(8, 4))
plt.plot(xs, density(xs))
plt.fill_between(xs, density(xs), alpha=0.3)
plt.xlabel("num_iterations")
plt.ylabel("Density")
plt.title(f"KDE of num_iterations, res_tol = {tol}, cut = {cut}")
plt.tight_layout()
plt.show()

# %%
tol = np.sort(df_all["solver_tol"].unique())[1]
cut = tol

df_now = df_all[
    (df_all["solver"] == "AMGCL") &
    (df_all["prename"] == "golf-ball-doformable-wall") &
    (df_all["solver_tol"] == tol)&
    (df_all["final_res_norm"] < cut)
    
]

data = df_now["num_iterations"].values
density = gaussian_kde(data)
xs = np.linspace(data.min(), data.max(), 200)

plt.figure(figsize=(8, 4))
plt.plot(xs, density(xs))
plt.fill_between(xs, density(xs), alpha=0.3)
plt.xlabel("num_iterations")
plt.ylabel("Density")
plt.title(f"KDE of num_iterations, res_tol = {tol}, cut = {cut}")
plt.tight_layout()
plt.show()

# %%
tol = np.sort(df_all["solver_tol"].unique())[2]
cut = tol

df_now = df_all[
    (df_all["solver"] == "AMGCL") &
    (df_all["prename"] == "golf-ball-doformable-wall") &
    (df_all["solver_tol"] == tol)&
    (df_all["final_res_norm"] < cut)
    
]

data = df_now["num_iterations"].values
density = gaussian_kde(data)
xs = np.linspace(data.min(), data.max(), 200)

plt.figure(figsize=(8, 4))
plt.plot(xs, density(xs))
plt.fill_between(xs, density(xs), alpha=0.3)
plt.xlabel("num_iterations")
plt.ylabel("Density")
plt.title(f"KDE of num_iterations, res_tol = {tol}, cut = {cut}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # filter out

# %%
# df_now = df_all[df_all["solver"] == "Trilinos"]
df_now = df_all[
    (df_all["solver"] == "AMGCL") &
    (df_all["solver_tol"] == 1e-10)&
    (df_all["final_res_norm"] < 1e-10)
    
]


def log_tick_formatter(val, pos=None):
    return r"$10^{%.1f}$" % val

plt.figure(figsize=(8, 6))
plt.scatter(np.log(df_now["mat_sz"]), np.log(df_now["elapse_time"]), alpha=0.7, s=10, label="elapse_time")


plt.gca().xaxis.set_major_formatter(FuncFormatter(log_tick_formatter))
plt.gca().yaxis.set_major_formatter(FuncFormatter(log_tick_formatter))

plt.xlabel("Matrix Size (log scale)")
plt.ylabel("time (log scale)")
plt.title("AMGCL: Time vs Matrix Size (log-log), 1 threads, clock time")
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.legend() 
plt.tight_layout()
plt.show()
