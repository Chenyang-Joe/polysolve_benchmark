# %%
import pandas as pd
from libs.parser import *

import matplotlib.pyplot as plt
from collections import defaultdict
from matplotlib.ticker import FuncFormatter

# %%
dataset_thread_1_dir = "/u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset"
golfball_thread_1_dir = "/u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset_golfball"
dataset_thread_32_dir = "/u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset"
golfball_thread_32_dir = "/u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset_golfball"

dir_list = [
    dataset_thread_1_dir,
    golfball_thread_1_dir,
    dataset_thread_32_dir,
    golfball_thread_32_dir
]

# %%
data_all = {}
for trial_dir in dir_list:
    data_trial = []  
    exp_name = trial_dir.split('/')[-1]
    print(f"processing the dir {exp_name}")
    for fname in os.listdir(trial_dir):
        
        
        if "Pardiso" in fname:
            solver = "Eigen::PardisoLDLT"
        elif "AMGCL" in fname:
            solver = "AMGCL"
        elif "Hypre" in fname:
            solver = "Hypre"

        log_path = os.path.join(trial_dir, fname)
        data = parse_log_file(log_path, solver)
        data_trial.extend(data)
    data_all[exp_name] = data_trial
# Out:
# processing the dir trial_thread_1_taskset
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/AMGCL_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-high-school-physics-slopetest-mu=0.49.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-cliff-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_dolphin-funnel.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_spike-in-hole.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_ball-rollers.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Eigen::PardisoLDLT_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_5-squares.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_friction-slope.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_edge-edge-parallel.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_wedge-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-spike-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-vertex-vertex.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_stretch-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-large-mass-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_disk-codim-points.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-golf-ball.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-large-stiffness-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_wedges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_golf-ball-P1.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_walking-elephant.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-arch.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_rod-twist.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-cliff-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_golf-ball-doformable-wall.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_squeeze-out.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-arch.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_5-cubes-fast.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-card-house.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_mat-twist.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_5-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_armadillo-roller.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_trash-compactor-shapes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-edge-edge.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_spike-and-wedge.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_circle-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_mooney_rivlin_p2.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_tet-corner.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_circle-rollers.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_mooney_rivlin.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-spike-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-large-stiffness-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_mat-knives.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-large-mass-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_rotating-slope.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_stick-slip.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-vertex-vertex.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_moving-ground.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_trash-compactor-octocat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-spikes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_golf-ball-P2.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_2D-high-school-physics-slopetest-mu=0.50.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-golf-ball.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_screw.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_3D-card-house.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset/Hypre_initial_angular_velocity.log, some experiments are skipped.
# processing the dir trial_thread_1_taskset_golfball
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset_golfball/Hypre_3D_golf_ball_189090_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset_golfball/Hypre_3D_golf_ball_vanilla_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset_golfball/Hypre_3D_golf_ball_113325_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset_golfball/Hypre_3D_golf_ball_73852_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_1_taskset_golfball/Hypre_3D_golf_ball_39376_try_larger_matrix_0.log, some experiments are skipped.
# processing the dir trial_thread_32_taskset
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/AMGCL_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-high-school-physics-slopetest-mu=0.49.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-cliff-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_dolphin-funnel.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_spike-in-hole.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_ball-rollers.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Eigen::PardisoLDLT_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_5-squares.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_friction-slope.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_edge-edge-parallel.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_wedge-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-spike-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-vertex-vertex.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_stretch-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-large-mass-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_disk-codim-points.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-golf-ball.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-large-stiffness-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_wedges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_golf-ball-P1.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_walking-elephant.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-arch.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_rod-twist.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-cliff-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_golf-ball-doformable-wall.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_squeeze-out.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-arch.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_5-cubes-fast.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-card-house.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_mat-twist.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_5-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_armadillo-roller.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_trash-compactor-shapes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-edge-edge.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_spike-and-wedge.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_circle-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_mooney_rivlin_p2.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_tet-corner.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_circle-rollers.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_mooney_rivlin.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-spike-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-large-stiffness-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_mat-knives.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-large-mass-ratio.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_rotating-slope.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_stick-slip.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-vertex-vertex.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_moving-ground.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_trash-compactor-octocat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-spikes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_golf-ball-P2.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_2D-high-school-physics-slopetest-mu=0.50.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-golf-ball.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_screw.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_3D-card-house.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset/Hypre_initial_angular_velocity.log, some experiments are skipped.
# processing the dir trial_thread_32_taskset_golfball
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset_golfball/Hypre_3D_golf_ball_189090_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset_golfball/Hypre_3D_golf_ball_vanilla_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset_golfball/Hypre_3D_golf_ball_113325_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset_golfball/Hypre_3D_golf_ball_73852_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/trial_thread_32_taskset_golfball/Hypre_3D_golf_ball_39376_try_larger_matrix_0.log, some experiments are skipped.

# %%
import pickle

with open('/u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/12_3_read_data.pkl', 'wb') as f:
    pickle.dump(data_all, f)

# %%
for exp_name, exp_data in data_all.items():
    print(f"Experiment: {exp_name}, Number of runs: {len(exp_data)}")
# Out:
# Experiment: trial_thread_1_taskset, Number of runs: 107179
# Experiment: trial_thread_1_taskset_golfball, Number of runs: 4115
# Experiment: trial_thread_32_taskset, Number of runs: 107179
# Experiment: trial_thread_32_taskset_golfball, Number of runs: 4119

# %%
grouped_data = []
for exp_name, exp_data in data_all.items():
    num_thread = int(exp_name.split("_")[2])
    for entry in exp_data:
        solver = entry["solver"]
        mat_sz = entry["mat_sz"]
        clock_time = entry["clock_time"]

        # Create label based on solver and tolerance
        if solver == "Eigen::PardisoLDLT":
            solver_name = "Pardiso"
        else:
            solver_name = solver

        this_data = {
            "solver_name": solver_name,
            "mat_sz": mat_sz,
            "clock_time": clock_time,
            "num_thread": num_thread
        }
        grouped_data.append(this_data)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(grouped_data)

# Filter num_thread = 1
df1 = df[df["num_thread"] == 1]
df1 = df1[df1["mat_sz"]>=1e4]

plt.figure(figsize=(8, 6))

# Scatter for each solver
for solver, sdf in df1.groupby("solver_name"):
    plt.scatter(
        sdf["mat_sz"],
        sdf["clock_time"],
        s=10,                # point size
        alpha=0.8,           # transparency
        label=solver
    )

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("Clock Time (ms, log scale)")
plt.title("Clock Time vs Matrix Size (num_thread = 1, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(grouped_data)

# Filter num_thread = 1
df1 = df[df["num_thread"] == 32]
df1 = df1[df1["mat_sz"]>=1e4]


plt.figure(figsize=(8, 6))

# Scatter for each solver
for solver, sdf in df1.groupby("solver_name"):
    plt.scatter(
        sdf["mat_sz"],
        sdf["clock_time"],
        s=10,                # point size
        alpha=0.8,           # transparency
        label=solver
    )

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("Clock Time (ms, log scale)")
plt.title("Clock Time vs Matrix Size (num_thread = 1, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(grouped_data)

current_solver = "AMGCL"
df1 = df[df["solver_name"] == current_solver]
# df1 = df1[df1["mat_sz"]>=1e4]


plt.figure(figsize=(8, 6))

# Scatter for each solver
for solver, sdf in df1.groupby("num_thread"):
    plt.scatter(
        sdf["mat_sz"],
        sdf["clock_time"],
        s=10,                # point size
        alpha=0.8,           # transparency
        label=solver
    )

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("Clock Time (ms, log scale)")
plt.title(f"Clock Time vs Matrix Size ({current_solver}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(grouped_data)

current_solver = "Hypre"
df1 = df[df["solver_name"] == current_solver]
# df1 = df1[df1["mat_sz"]>=1e4]


plt.figure(figsize=(8, 6))

# Scatter for each solver
for solver, sdf in df1.groupby("num_thread"):
    plt.scatter(
        sdf["mat_sz"],
        sdf["clock_time"],
        s=10,                # point size
        alpha=0.8,           # transparency
        label=solver
    )

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("Clock Time (ms, log scale)")
plt.title(f"Clock Time vs Matrix Size ({current_solver}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(grouped_data)

current_solver = "Pardiso"
df1 = df[df["solver_name"] == current_solver]
# df1 = df1[df1["mat_sz"]>=1e4]


plt.figure(figsize=(8, 6))

# Scatter for each solver
for solver, sdf in df1.groupby("num_thread"):
    plt.scatter(
        sdf["mat_sz"],
        sdf["clock_time"],
        s=10,                # point size
        alpha=0.8,           # transparency
        label=solver
    )

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("Clock Time (ms, log scale)")
plt.title(f"Clock Time vs Matrix Size ({current_solver}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
