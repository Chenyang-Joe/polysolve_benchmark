# %%
import pandas as pd
from libs.parser import *

import matplotlib.pyplot as plt
from collections import defaultdict
from matplotlib.ticker import FuncFormatter

import pandas as pd
import matplotlib.pyplot as plt

from matplotlib.colors import LogNorm

import numpy as np
from scipy.interpolate import UnivariateSpline
import matplotlib.cm as cm

# %%
data_dir = "/u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together"
data_all = []

# %%
for current_dir in os.listdir(data_dir):
    index = int(current_dir.split("_")[-1])
    num_threads = 2**(index-1)
    full_dir = os.path.join(data_dir, current_dir)
    for fname in os.listdir(full_dir):
        if "Pardiso" in fname:
            solver = "Eigen::PardisoLDLT"
        elif "AMGCL" in fname:
            solver = "AMGCL"
        elif "Hypre" in fname:
            solver = "Hypre"
        elif "Trilinos" in fname:
            solver = "Trilinos"
        log_path = os.path.join(full_dir, fname)
        data = parse_log_file(log_path, solver)
        for i, entry in enumerate(data):
            data[i]["num_threads"] = num_threads
        data_all.extend(data)
# Out:
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Trilinos_3D_golf_ball_39376_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Hypre_3D_golf_ball_189090_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Trilinos_3D_golf_ball_73852_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Trilinos_3D_golf_ball_vanilla_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Trilinos_3D_golf_ball_189090_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Hypre_3D_golf_ball_vanilla_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Trilinos_3D_golf_ball_113325_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Hypre_3D_golf_ball_113325_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Hypre_3D_golf_ball_73852_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/golf_ball_1/Hypre_3D_golf_ball_39376_try_larger_matrix_0.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/AMGCL_sphere-mat.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_3D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_3D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_2D-cliff-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_golf-ball-P2.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_5-cubes.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_ball-rollers.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_disk-codim-points.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_dolphin-funnel.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_spike-in-hole.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_2D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_ball-rollers.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Eigen::PardisoLDLT_sphere-mat.log, some experiments are skipped.
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# mat size exception: index 0 is out of bounds for axis 0 with size 0
# nnz exception: index 2 is out of bounds for axis 0 with size 0
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_5-squares.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_5-squares.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_friction-slope.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_screw.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_edge-edge-parallel.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_wedge-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_2D-spike-in-crack.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Hypre_2D-internal-edges.log, some experiments are skipped.
# Warning: errors detected in log file /u/1/chenyang/benchmark_data/larger_matrix_exp/larger_mat_exp_result/2026-1-14/all_together/old_data_1/Trilinos_friction-slope.log, some experiments are skipped.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 15
#      13     solver = "Trilinos"
#      14 log_path = os.path.join(full_dir, fname)
# ---> 15 data = parse_log_file(log_path, solver)
#      16 for i, entry in enumerate(data):
#      17     data[i]["num_threads"] = num_threads
#
# File ~/benchmark/analysis/libs/parser.py:169, in parse_log_file(fname, solver)
#     168 def parse_log_file(fname, solver):
# --> 169     seq = sequence_data(fname, solver)
#     171     log_data = []
#     172     for entry in seq:
#
# File ~/benchmark/analysis/libs/parser.py:80, in sequence_data(fname, solver)
#      78     element["elapse_time"] = float(lines[end_i-1].split(" ")[-1].strip().rstrip("s"))
#      79 elif solver == "AMGCL" or solver == "Trilinos":
# ---> 80     element["factorize"] = float(lines[end_i-12].split(" ")[-1].strip().rstrip("s"))
#      81     element["solve"] = float(lines[end_i-11].split(" ")[-1].strip().rstrip("s"))
#      82     element["residual"] = float(lines[end_i-10].split(" ")[-1].strip())
#
# ValueError: could not convert string to float: ''

# %%
import pickle
save_path = "tmp_save_28.pkl"
with open(save_path, "wb") as f:
    pickle.dump(data_all, f)

# %%
print(data_all[0].keys())
# Out:
# dict_keys(['log_path', 'solver', 'bin_A', 'bin_b', 'mat_sz', 'nnz', 'density', 'sparsity', 'outer', 'inner', 'residual', 'clock_time', 'elapse_time', 'num_threads'])

# %%
grouped_data = []
for entry in data_all:
    solver = entry["solver"]
    mat_sz = entry["mat_sz"]
    elapse_time = entry["elapse_time"]
    num_threads = entry["num_threads"]
    if "num_iterations" in entry.keys():
        num_iterations = entry["num_iterations"]
    else:
        num_iterations = 0

    this_data = {
        "solver_name": solver,
        "mat_sz": mat_sz,
        "elapse_time": elapse_time,
        "num_iterations": num_iterations,
        "num_threads": num_threads
    }
    grouped_data.append(this_data)

# %%
df = pd.DataFrame(grouped_data)
thread_values = sorted(df["num_threads"].unique())
print(thread_values)
# Out:
# [1]

# %% [markdown]
# Plot 1: trilinos curve, thread = 1, time vs mat size
#
# Plot 2: trilinos curve, different threads, time vs mat size
#
# Plot 3: Pardiso curve, different threads, time vs mat size
#
# Plot 4: 4 curves, thread = 1, time vs mat size

# %%
current_source = "Trilinos"
df1 = df[df["solver_name"] == current_source]
df1 = df1[df1["mat_sz"]>=1e4]
df1 = df1[df1["num_threads"]==1]
plt.figure(figsize=(8, 6))

offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("solver_name"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset += .02

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title("Trilinos, elapse_time vs Matrix Size (num_thread = 1, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
current_solver = "Trilinos"
df1 = df[df["solver_name"] == current_solver]
df1 = df1[df1["mat_sz"]>=1e4]

thread_values = sorted(df1["num_threads"].unique())
cmap = cm.get_cmap("tab20", len(thread_values))

print(thread_values)

plt.figure(figsize=(8, 6))

# Scatter for each solver
offset = 1
for idx, (nthreads, sdf) in enumerate(df1.groupby("num_threads")):
    
    color = cmap(idx)   # same color for raw + mean

    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        color = color,
        label=nthreads
    )

    g = sdf.groupby("mat_sz")["elapse_time"].mean().reset_index()
    g = g.sort_values("mat_sz")

    plt.scatter(
        g["mat_sz"] * offset,
        g["elapse_time"],
        s=40,                 # larger marker for mean
        marker="x",           # or "o"
        color = color,
        label=f"{nthreads} threads (mean)"
    )
    
    offset *= 1.02



plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"elapse_time vs Matrix Size ({current_solver}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2574831/2459339916.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", len(thread_values))
# [1]

# %%
current_solver = "Eigen::PardisoLDLT"
current_source = "pardiso_control_threads"
df1 = df[df["source"] == current_source]
df1 = df1[df1["solver_name"] == current_solver]
df1 = df1[df1["mat_sz"]>=1e4]

thread_values = sorted(df1["num_threads"].unique())
cmap = cm.get_cmap("tab20", len(thread_values))


plt.figure(figsize=(8, 6))

# Scatter for each solver
offset = 1
for idx, (nthreads, sdf) in enumerate(df1.groupby("num_threads")):
    
    color = cmap(idx)   # same color for raw + mean

    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        color = color,
        label=nthreads
    )

    g = sdf.groupby("mat_sz")["elapse_time"].mean().reset_index()
    g = g.sort_values("mat_sz")

    plt.scatter(
        g["mat_sz"] * offset,
        g["elapse_time"],
        s=40,                 # larger marker for mean
        marker="x",           # or "o"
        color = color,
        label=f"{nthreads} threads (mean)"
    )
    
    offset *= 1.02



plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"elapse_time vs Matrix Size ({current_solver}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_711087/1877422097.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", len(thread_values))

# %%
current_solver = "Eigen::PardisoLDLT"
num_threads = 1
# current_source = "pardiso_control_threads"
# df1 = df[df["source"] == current_source]
df1 = df[df["solver_name"] == current_solver]
df1 = df1[df1["mat_sz"]>=1e4]
df1 = df1[df1["num_threads"]==num_threads]

thread_values = sorted(df1["num_threads"].unique())
cmap = cm.get_cmap("tab20", len(thread_values))


plt.figure(figsize=(8, 6))
offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("source"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset *= 1.01

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"Pardiso, elapse_time vs Matrix Size (num_thread = {num_threads}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_711087/3318442412.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", len(thread_values))

# %%
current_solver = "Eigen::PardisoLDLT"
num_threads = 2
# current_source = "pardiso_control_threads"
# df1 = df[df["source"] == current_source]
df1 = df[df["solver_name"] == current_solver]
df1 = df1[df1["mat_sz"]>=1e4]
df1 = df1[df1["num_threads"]==num_threads]

thread_values = sorted(df1["num_threads"].unique())
cmap = cm.get_cmap("tab20", len(thread_values))


plt.figure(figsize=(8, 6))
offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("source"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset *= 1.01

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"Pardiso, elapse_time vs Matrix Size (num_thread = {num_threads}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_711087/1484345347.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", len(thread_values))

# %%
current_solver = "Eigen::PardisoLDLT"
num_threads = 4
# current_source = "pardiso_control_threads"
# df1 = df[df["source"] == current_source]
df1 = df[df["solver_name"] == current_solver]
df1 = df1[df1["mat_sz"]>=1e4]
df1 = df1[df1["num_threads"]==num_threads]

thread_values = sorted(df1["num_threads"].unique())
cmap = cm.get_cmap("tab20", len(thread_values))


plt.figure(figsize=(8, 6))
offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("source"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset *= 1.01

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"Pardiso, elapse_time vs Matrix Size (num_thread = {num_threads}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_711087/878412650.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", len(thread_values))

# %%
current_solver = "Eigen::PardisoLDLT"
num_threads = 8
# current_source = "pardiso_control_threads"
# df1 = df[df["source"] == current_source]
df1 = df[df["solver_name"] == current_solver]
df1 = df1[df1["mat_sz"]>=1e4]
df1 = df1[df1["num_threads"]==num_threads]

thread_values = sorted(df1["num_threads"].unique())
cmap = cm.get_cmap("tab20", len(thread_values))


plt.figure(figsize=(8, 6))
offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("source"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset *= 1.01

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"Pardiso, elapse_time vs Matrix Size (num_thread = {num_threads}, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_711087/1570948267.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", len(thread_values))

# %%
current_solver = "Trilinos"
current_source = "trilinos_dev"
df1 = df[df["source"] == current_source]
df1 = df1[df1["solver_name"] == current_solver]
df1 = df1[df1["mat_sz"]>=1e4]
df1 = df1[df1["num_threads"]==1]


current_solver = "Eigen::PardisoLDLT"
# current_source = "pardiso_control_threads"
# df2 = df[df["source"] == current_source]
df2 = df[df["solver_name"] == current_solver]
df2 = df2[df2["mat_sz"]>=1e4]
df2 = df2[df2["num_threads"]==1]
df2["solver_name"] = "Pardiso_taskset"


current_solver = "AMGCL"
current_source = "taskset"
df3 = df[df["source"] == current_source]
df3 = df3[df3["solver_name"] == current_solver]
df3 = df3[df3["mat_sz"]>=1e4]
df3 = df3[df3["num_threads"]==1]
df3["solver_name"] = "AMGCL_taskset"


current_solver = "Hypre"
current_source = "taskset"
df4 = df[df["source"] == current_source]
df4 = df4[df4["solver_name"] == current_solver]
df4 = df4[df4["mat_sz"]>=1e4]
df4 = df4[df4["num_threads"]==1]
df4["solver_name"] = "Hypre_taskset"


df_1234 = pd.concat(
    [df1, df2, df3, df4],
    axis=0,          # 行方向拼接（默认）
    ignore_index=True
)

# %%
# Filter num_thread = 1
df1 = df_1234[df_1234["mat_sz"]>=1e4]

plt.figure(figsize=(8, 6))
offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("solver_name"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset *= 1.01

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"elapse_time vs Matrix Size (num_thread = 1, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Filter num_thread = 1
df1 = df_1234[df_1234["mat_sz"]>=1e4]
df1 = df1[df1["solver_name"]!="AMGCL_taskset"]

plt.figure(figsize=(8, 6))
offset = 1
# Scatter for each solver
for solver, sdf in df1.groupby("solver_name"):
    plt.scatter(
        sdf["mat_sz"]*offset,
        sdf["elapse_time"],
        s=1,                # point size
        alpha=0.8,           # transparency
        label=solver
    )
    offset *= 1.01

plt.xscale("log")
plt.yscale("log")

plt.xlabel("Matrix Size (mat_sz, log scale)")
plt.ylabel("elapse_time (s, log scale)")
plt.title(f"elapse_time vs Matrix Size (num_thread = 1, log-log scatter)")
plt.legend()
# plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
